# %%
import numpy  as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data  = pd.read_csv("House_Rent_Dataset.csv")

# %%
data.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
duplicate_values = data.duplicated().sum()
duplicate_values
# Out:
# np.int64(0)

# %%
data = data.drop(['Posted On','Floor','Area Locality'],axis=1)
data
# Out:
#       BHK   Rent  Size    Area Type       City Furnishing Status  \
# 0       2  10000  1100   Super Area    Kolkata       Unfurnished
# 1       2  20000   800   Super Area    Kolkata    Semi-Furnished
# 2       2  17000  1000   Super Area    Kolkata    Semi-Furnished
# 3       2  10000   800   Super Area    Kolkata       Unfurnished
# 4       2   7500   850  Carpet Area    Kolkata       Unfurnished
# ...   ...    ...   ...          ...        ...               ...
# 4741    2  15000  1000  Carpet Area  Hyderabad    Semi-Furnished
# 4742    3  29000  2000   Super Area  Hyderabad    Semi-Furnished
# 4743    3  35000  1750  Carpet Area  Hyderabad    Semi-Furnished
# 4744    3  45000  1500  Carpet Area  Hyderabad    Semi-Furnished
# 4745    2  15000  1000  Carpet Area  Hyderabad       Unfurnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 0     Bachelors/Family         2    Contact Owner
# 1     Bachelors/Family         1    Contact Owner
# 2     Bachelors/Family         1    Contact Owner
# 3     Bachelors/Family         1    Contact Owner
# 4            Bachelors         1    Contact Owner
# ...                ...       ...              ...
# 4741  Bachelors/Family         2    Contact Owner
# 4742  Bachelors/Family         3    Contact Owner
# 4743  Bachelors/Family         3    Contact Agent
# 4744            Family         2    Contact Agent
# 4745         Bachelors         2    Contact Owner
#
# [4746 rows x 9 columns]

# %%
import seaborn as sns
plt.figure(figsize=(14,15))
for i,col in enumerate(['Area Type','City','Furnishing Status','Tenant Preferred','Point of Contact']):
    plt.subplot(4,2,i+1)
    sns.countplot(data=data,x=col)

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=data,x="Rent",y="Size",hue="City")
# Out:
# <Axes: xlabel='Rent', ylabel='Size'>

# %%
sns.barplot(data=data,x="City",y="Rent")
plt.title("Average rent by the city ")
plt.show()

# %%
sns.barplot(data=data,x="Tenant Preferred",y="Rent")
plt.title("Average rent by Tenant Preferred")
plt.show()

# %%
! pip install xgboost
! pip install category_encoders
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.svm import SVR
import sklearn.metrics as metrics
import xgboost as xgb
import category_encoders as ce
from sklearn.preprocessing import MinMaxScaler
# Out:
# Requirement already satisfied: xgboost in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: scipy in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from xgboost) (1.14.1)
# Collecting category_encoders
#   Downloading category_encoders-2.8.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (2.2.3)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting scikit-learn>=1.6.0 (from category_encoders)
#   Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.14.1)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\adity\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.16.0)
# Downloading category_encoders-2.8.0-py3-none-any.whl (85 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.8 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.8 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.8 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.8 MB 1.9 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.6/9.8 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.8 MB 1.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.9/9.8 MB 1.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.2/9.8 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 5.0/9.8 MB 1.9 MB/s eta 0:00:03
#    --------------------- ------------------ 5.2/9.8 MB 1.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/9.8 MB 1.9 MB/s eta 0:00:03
#    ------------------------ --------------- 6.0/9.8 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.8 MB 1.9 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.8 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.8 MB 1.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/9.8 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/9.8 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/9.8 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 7.9/9.8 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 1.5 MB/s eta 0:00:00
# Installing collected packages: patsy, scikit-learn, statsmodels, category_encoders
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.0
#     Uninstalling scikit-learn-1.5.0:
#       Successfully uninstalled scikit-learn-1.5.0
# Successfully installed category_encoders-2.8.0 patsy-1.0.1 scikit-learn-1.6.1 statsmodels-0.14.4
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 11
#       9 import sklearn.metrics as metrics
#      10 import xgboost as xgb
# ---> 11 import category_encoders as ce
#      12 from sklearn.preprocessing import MinMaxScaler
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\category_encoders\__init__.py:9
#       1 """Category encoders library.
#       2
#       3 .. module:: category_encoders
#    (...)
#       6
#       7 """
# ----> 9 from category_encoders.backward_difference import BackwardDifferenceEncoder
#      10 from category_encoders.basen import BaseNEncoder
#      11 from category_encoders.binary import BinaryEncoder
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\category_encoders\backward_difference.py:6
#       3 import numpy as np
#       4 from patsy.contrasts import ContrastMatrix, Diff
# ----> 6 from category_encoders.base_contrast_encoder import BaseContrastEncoder
#       8 __author__ = 'paulwestenthanner'
#      11 class BackwardDifferenceEncoder(BaseContrastEncoder):
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\category_encoders\base_contrast_encoder.py:9
#       6 import pandas as pd
#       7 from patsy.contrasts import ContrastMatrix
# ----> 9 import category_encoders.utils as util
#      10 from category_encoders.ordinal import OrdinalEncoder
#      12 __author__ = 'paulwestenthanner'
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\category_encoders\utils.py:20
#      18 from sklearn.exceptions import NotFittedError
#      19 from sklearn.preprocessing import LabelEncoder
# ---> 20 from sklearn.utils import Tags
#      22 __author__ = 'willmcginnis'
#      24 X_type = np.ndarray | pd.DataFrame | list | np.generic | csr_matrix
#
# ImportError: cannot import name 'Tags' from 'sklearn.utils' (c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\__init__.py)
